# %% [markdown]
# ##  Importação bibliotecas

# %%
import utente
import pandas as pd
import pandas_profiling as pandasprof

import importlib as imp
import sys

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Configurações

# %%
pd.options.display.max_columns = 100

# %% [markdown]
# ## Carregamento dos dados

# %% [markdown]
# Em máquina Windows ocorre regularmente "Memory Error", provavelmente devido a algumas variáveis que não são limpas ou à cache do servidor do Jupyter. <br>
# Um **fix** temporário (se não tivermos o ficheiro local PICKLE) pode ser:
# 1. Carregar utente.ListaUtentes com forceFetch = True <br>
# 2. Guardar localmente estrutura objectos em ficheiro PICKLE com output2FileHistoricosTodosUtentes() <br>
# 3. Fechar e voltar a abrir o Notebook <br>
# 4. Carregar utente.ListaUtentes com forceFetch = False <br>
# 5. Carregar o Pandas Dataframe com pd.DataFrame(listaUtentes.generateDataset())

# %%
# Opcional: Reload módulo utente
imp.reload(sys.modules['utente']);

# %%
# Carregamento estrutura dados (passar parâmetro forceFetch = True para forçar leitura BD >> Demorado!)
listaUtentes = utente.ListaUtentes(forceFetch = True, sqlLimit = 99999999999) # Carrega dados locais a partir de PICKLE
# Out:
# Criar ligação MySQL
# Parsing da tabela pedidos_inscritos_longos... (1/7)
# Parsing das Anulacoes... (2/7)
# Total de 4109 (3%) utentes existentes em sie_31 mas sem equivalencia na pedidos_inscritos_longos:
# Parse das Intervenções... (3/7)
# Total de 20285 (4%) utentes existentes em sie_35 mas sem equivalencia na pedidos_inscritos_longos:
# Parse dos Encaminhamentos... (4/7)
# Total de 9761 (7%) utentes existentes em sie_36 mas sem equivalencia na pedidos_inscritos_longos:
# Parse dos Apresentações... (5/7)
# Total de 4217 (2%) utentes existentes em pd_sie_37 mas sem equivalencia na pedidos_inscritos_longos:
# Parse das Convocatórias... (6/7)
# Total de 11899 (4%) utentes existentes em pd_sie_38 mas sem equivalencia na pedidos_inscritos_longos:
# Parse das Mudanças de Categoria... (7/7)
# Total de 7052 (5%) utentes existentes em pd_sie_43 mas sem equivalencia na pedidos_inscritos_longos:
# Finalizado com Sucesso!

# %%
# Guarda o Pickel localmente
listaUtentes.save()
# Out:
# Saving to ./temp/ListaUtentes.pickle

# %%
# Opcional: Output do Histórico de todos Utentes para txt >> Demorado!
#listaUtentes.output2FileHistoricosTodosUtentes()

# %%
# Criação do dataframe pandas
df = pd.DataFrame(listaUtentes.generateDataset())
listaUtentes = None # Limpa listaUtentes depois de gerar Dataset

# %%
# Listagem Colunas do dataframe
[print(col) for col in df];
# Out:
# AreaCurso
# AreaFormacao
# CategoriaAtrib
# CnpAnterior
# ConjugeMotivoIndisponibilidade
# CursoAnoConclusao
# CursoEstabelecimentoEnsinoSup
# Data
# DataNascimento
# DiasDesemprego
# Empregado
# EstadoCivil
# FormacaoProf
# HabilitacaoEscolar
# Idade
# LTU
# Nacionalidade
# NivelDeficiencia
# NrAnulacoes
# NrAnulacoesPorMotivo_CADUCIDADE DO DOCUMENTO DE IDENTIFICAÇÃO
# NrAnulacoesPorMotivo_COLOCAÇÃO - CANDIDATURA EXTERNA
# NrAnulacoesPorMotivo_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA DE OUTREM
# NrAnulacoesPorMotivo_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA PRÓPRIA
# NrAnulacoesPorMotivo_CORRECÇÃO COLOCAÇÃO FME
# NrAnulacoesPorMotivo_CORRECÇÃO REINSCRIÇÃO FME
# NrAnulacoesPorMotivo_CRIAÇÃO DO PRÓPRIO EMPREGO
# NrAnulacoesPorMotivo_CUMPRIMENTO SERVIÇO MILITAR
# NrAnulacoesPorMotivo_DESISTIU
# NrAnulacoesPorMotivo_DESISTÊNCIA OU EXCLUSÃO DE FORMAÇÃO
# NrAnulacoesPorMotivo_DESISTÊNCIA OU EXCLUSÃO DE MEDIDAS DE EMPREGO (EXCLUI TRABALHO SOCIALMENTE NECESSÁRIO)
# NrAnulacoesPorMotivo_DESISTÊNCIA OU EXCLUSÃO DE TRABALHO SOCIALMENTE NECESSÁRIO
# NrAnulacoesPorMotivo_DETENÇÃO EM ESTABELECIMENTO PRISIONAL
# NrAnulacoesPorMotivo_EMIGRAÇÃO, AUSÊNCIA DO PAÍS
# NrAnulacoesPorMotivo_FALECIMENTO
# NrAnulacoesPorMotivo_FALTA A CONVOCATÓRIA
# NrAnulacoesPorMotivo_FALTA AO CONTROLO
# NrAnulacoesPorMotivo_FALTA À APRESENTAÇÃO
# NrAnulacoesPorMotivo_FREQUÊNCIA DE CURSO DE FORMAÇÃO PROFISSIONAL DO IEFP
# NrAnulacoesPorMotivo_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAC
# NrAnulacoesPorMotivo_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAL
# NrAnulacoesPorMotivo_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAP
# NrAnulacoesPorMotivo_FREQUÊNCIA DE FORMAÇÃO DO IEFP (ENTRADA SGFOR)
# NrAnulacoesPorMotivo_FREQUÊNCIA DE FORMAÇÃO EM ENTIDADE EXTERNA AO IEFP
# NrAnulacoesPorMotivo_INCAPACIDADE PROLONGADA / PERMANENTE PARA O TRABALHO
# NrAnulacoesPorMotivo_INCUMPRIMENTO DA APRESENTAÇÃO QUINZENAL
# NrAnulacoesPorMotivo_INSCRIÇÃO CANDIDATURA EXTERNA
# NrAnulacoesPorMotivo_INSERÇÃO NOUTROS PROGRAMAS/MEDIDAS EMPREGO (SIEF)
# NrAnulacoesPorMotivo_INSERÇÃO POR CONTA OUTRÉM, NA SEQUÊNCIA DE PROGRAMA
# NrAnulacoesPorMotivo_INÍCIO DE LICENÇA DE MATERNIDADE, PATERNIDADE OU ADOPÇÃO
# NrAnulacoesPorMotivo_OUTROS MOTIVOS
# NrAnulacoesPorMotivo_RECUSA DE EMPREGO CONVENIENTE
# NrAnulacoesPorMotivo_RECUSA DE FORMALIZAÇÃO DE PPE
# NrAnulacoesPorMotivo_RECUSA DE FORMAÇÃO PROFISSIONAL
# NrAnulacoesPorMotivo_RECUSA DE INTERVENÇÃO
# NrAnulacoesPorMotivo_RECUSA DE TRABALHO SOCIALMENTE NECESSÁRIO
# NrAnulacoesPorMotivo_REFORMOU-SE
# NrAnulacoesPorMotivo_REINÍCIO DE ESTUDOS
# NrAnulacoesPorMotivo_TRANSFERÊNCIA DE CENTRO DE EMPREGO
# NrAnulacoesPorMotivo_TRANSFERÊNCIA REGIÕES AUTÓNOMAS
# NrApresentacoes
# NrApresentacoesComResultado_CADUCIDADE DO DOCUMENTO DE IDENTIFICAÇÃO
# NrApresentacoesComResultado_COLOCAÇÃO - CANDIDATURA EXTERNA
# NrApresentacoesComResultado_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA DE OUTREM
# NrApresentacoesComResultado_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA PRÓPRIA
# NrApresentacoesComResultado_CORRECÇÃO COLOCAÇÃO FME
# NrApresentacoesComResultado_CORRECÇÃO REINSCRIÇÃO FME
# NrApresentacoesComResultado_CRIAÇÃO DO PRÓPRIO EMPREGO
# NrApresentacoesComResultado_CUMPRIMENTO SERVIÇO MILITAR
# NrApresentacoesComResultado_DESISTIU
# NrApresentacoesComResultado_DESISTÊNCIA OU EXCLUSÃO DE FORMAÇÃO
# NrApresentacoesComResultado_DESISTÊNCIA OU EXCLUSÃO DE MEDIDAS DE EMPREGO (EXCLUI TRABALHO SOCIALMENTE NECESSÁRIO)
# NrApresentacoesComResultado_DESISTÊNCIA OU EXCLUSÃO DE TRABALHO SOCIALMENTE NECESSÁRIO
# NrApresentacoesComResultado_DETENÇÃO EM ESTABELECIMENTO PRISIONAL
# NrApresentacoesComResultado_EMIGRAÇÃO, AUSÊNCIA DO PAÍS
# NrApresentacoesComResultado_FALECIMENTO
# NrApresentacoesComResultado_FALTA A CONVOCATÓRIA
# NrApresentacoesComResultado_FALTA AO CONTROLO
# NrApresentacoesComResultado_FALTA À APRESENTAÇÃO
# NrApresentacoesComResultado_FREQUÊNCIA DE CURSO DE FORMAÇÃO PROFISSIONAL DO IEFP
# NrApresentacoesComResultado_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAC
# NrApresentacoesComResultado_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAL
# NrApresentacoesComResultado_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAP
# NrApresentacoesComResultado_FREQUÊNCIA DE FORMAÇÃO DO IEFP (ENTRADA SGFOR)
# NrApresentacoesComResultado_FREQUÊNCIA DE FORMAÇÃO EM ENTIDADE EXTERNA AO IEFP
# NrApresentacoesComResultado_INCAPACIDADE PROLONGADA / PERMANENTE PARA O TRABALHO
# NrApresentacoesComResultado_INCUMPRIMENTO DA APRESENTAÇÃO QUINZENAL
# NrApresentacoesComResultado_INSCRIÇÃO CANDIDATURA EXTERNA
# NrApresentacoesComResultado_INSERÇÃO NOUTROS PROGRAMAS/MEDIDAS EMPREGO (SIEF)
# NrApresentacoesComResultado_INSERÇÃO POR CONTA OUTRÉM, NA SEQUÊNCIA DE PROGRAMA
# NrApresentacoesComResultado_INÍCIO DE LICENÇA DE MATERNIDADE, PATERNIDADE OU ADOPÇÃO
# NrApresentacoesComResultado_OUTROS MOTIVOS
# NrApresentacoesComResultado_RECUSA DE EMPREGO CONVENIENTE
# NrApresentacoesComResultado_RECUSA DE FORMALIZAÇÃO DE PPE
# NrApresentacoesComResultado_RECUSA DE FORMAÇÃO PROFISSIONAL
# NrApresentacoesComResultado_RECUSA DE INTERVENÇÃO
# NrApresentacoesComResultado_RECUSA DE TRABALHO SOCIALMENTE NECESSÁRIO
# NrApresentacoesComResultado_REFORMOU-SE
# NrApresentacoesComResultado_REINÍCIO DE ESTUDOS
# NrApresentacoesComResultado_TRANSFERÊNCIA DE CENTRO DE EMPREGO
# NrApresentacoesComResultado_TRANSFERÊNCIA REGIÕES AUTÓNOMAS
# NrConvocatorias
# NrDescendentesCargo
# NrEncaminhamentos
# NrInscricoes
# NrIntervencoes
# NrMudancasCategoria
# NrPessoasCargo
# Qualificacao
# RSI
# Sexo
# Utente

# %%
df.describe(include = 'all')
# Out:
#        AreaCurso            AreaFormacao             CategoriaAtrib  \
# count      22280                   23626                     123701
# unique      1528                     100                          4
# top       GESTÃO  GESTÃO E ADMINISTRAÇÃO  DESEMPREGADO-NOVO EMPREGO
# freq         729                    2691                     105664
# first        NaN                     NaN                        NaN
# last         NaN                     NaN                        NaN
# mean         NaN                     NaN                        NaN
# std          NaN                     NaN                        NaN
# min          NaN                     NaN                        NaN
# 25%          NaN                     NaN                        NaN
# 50%          NaN                     NaN                        NaN
# 75%          NaN                     NaN                        NaN
# max          NaN                     NaN                        NaN
#
#                   CnpAnterior ConjugeMotivoIndisponibilidade  \
# count                   99687                             23
# unique                   1129                              3
# top     ESCRITURÁRIO,EM GERAL                             01
# freq                     6384                             12
# first                     NaN                            NaN
# last                      NaN                            NaN
# mean                      NaN                            NaN
# std                       NaN                            NaN
# min                       NaN                            NaN
# 25%                       NaN                            NaN
# 50%                       NaN                            NaN
# 75%                       NaN                            NaN
# max                       NaN                            NaN
#
#        CursoAnoConclusao CursoEstabelecimentoEnsinoSup                 Data  \
# count              22375                         22352               123701
# unique                58                           319                 4062
# top               2007,0                          2400  2013-09-02 00:00:00
# freq                1562                          1335                  162
# first                NaN                           NaN  1994-12-09 00:00:00
# last                 NaN                           NaN  2017-04-28 00:00:00
# mean                 NaN                           NaN                  NaN
# std                  NaN                           NaN                  NaN
# min                  NaN                           NaN                  NaN
# 25%                  NaN                           NaN                  NaN
# 50%                  NaN                           NaN                  NaN
# 75%                  NaN                           NaN                  NaN
# max                  NaN                           NaN                  NaN
#
#                  DataNascimento  DiasDesemprego Empregado EstadoCivil  \
# count                     47223   123701.000000    123701      123701
# unique                    14507             NaN         3           7
# top     1963/07/07 00:00:00.000             NaN         N           S
# freq                         35             NaN     92751       68657
# first                       NaN             NaN       NaN         NaN
# last                        NaN             NaN       NaN         NaN
# mean                        NaN      314.964277       NaN         NaN
# std                         NaN      435.692692       NaN         NaN
# min                         NaN        0.000000       NaN         NaN
# 25%                         NaN       77.000000       NaN         NaN
# 50%                         NaN      161.000000       NaN         NaN
# 75%                         NaN      405.000000       NaN         NaN
# max                         NaN    69919.000000       NaN         NaN
#
#        FormacaoProf HabilitacaoEscolar          Idade     LTU Nacionalidade  \
# count         31506             123701  123701.000000  123701        123701
# unique            2                 12            NaN       3           105
# top               N            12 ANOS            NaN       ?      PORTUGAL
# freq          27324              35322            NaN   75459         98223
# first           NaN                NaN            NaN     NaN           NaN
# last            NaN                NaN            NaN     NaN           NaN
# mean            NaN                NaN      36.448638     NaN           NaN
# std             NaN                NaN      12.088167     NaN           NaN
# min             NaN                NaN      14.000000     NaN           NaN
# 25%             NaN                NaN      26.000000     NaN           NaN
# 50%             NaN                NaN      35.000000     NaN           NaN
# 75%             NaN                NaN      45.000000     NaN           NaN
# max             NaN                NaN      99.000000     NaN           NaN
#
#         NivelDeficiencia    NrAnulacoes  \
# count      123701.000000  123701.000000
# unique               NaN            NaN
# top                  NaN            NaN
# freq                 NaN            NaN
# first                NaN            NaN
# last                 NaN            NaN
# mean            0.047178       0.978391
# std             0.300480       1.429562
# min             0.000000       0.000000
# 25%             0.000000       0.000000
# 50%             0.000000       0.000000
# 75%             0.000000       1.000000
# max             2.000000      15.000000
#
#         NrAnulacoesPorMotivo_CADUCIDADE DO DOCUMENTO DE IDENTIFICAÇÃO  \
# count                                          194.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.036082
# std                                              0.186978
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrAnulacoesPorMotivo_COLOCAÇÃO - CANDIDATURA EXTERNA  \
# count                                                 2.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA DE OUTREM  \
# count                                        19499.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.532130
# std                                              1.178774
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              2.000000
# max                                             14.000000
#
#         NrAnulacoesPorMotivo_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA PRÓPRIA  \
# count                                          944.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.193856
# std                                              0.629366
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              6.000000
#
#         NrAnulacoesPorMotivo_CORRECÇÃO COLOCAÇÃO FME  \
# count                                            3.0
# unique                                           NaN
# top                                              NaN
# freq                                             NaN
# first                                            NaN
# last                                             NaN
# mean                                             1.0
# std                                              0.0
# min                                              1.0
# 25%                                              1.0
# 50%                                              1.0
# 75%                                              1.0
# max                                              1.0
#
#         NrAnulacoesPorMotivo_CORRECÇÃO REINSCRIÇÃO FME  \
# count                                              4.0
# unique                                             NaN
# top                                                NaN
# freq                                               NaN
# first                                              NaN
# last                                               NaN
# mean                                               1.0
# std                                                0.0
# min                                                1.0
# 25%                                                1.0
# 50%                                                1.0
# 75%                                                1.0
# max                                                1.0
#
#         NrAnulacoesPorMotivo_CRIAÇÃO DO PRÓPRIO EMPREGO  \
# count                                             111.0
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# first                                               NaN
# last                                                NaN
# mean                                                1.0
# std                                                 0.0
# min                                                 1.0
# 25%                                                 1.0
# 50%                                                 1.0
# 75%                                                 1.0
# max                                                 1.0
#
#         NrAnulacoesPorMotivo_CUMPRIMENTO SERVIÇO MILITAR  \
# count                                                2.0
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# first                                                NaN
# last                                                 NaN
# mean                                                 1.0
# std                                                  0.0
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#         NrAnulacoesPorMotivo_DESISTIU  \
# count                      948.000000
# unique                            NaN
# top                               NaN
# freq                              NaN
# first                             NaN
# last                              NaN
# mean                         1.034810
# std                          0.210223
# min                          1.000000
# 25%                          1.000000
# 50%                          1.000000
# 75%                          1.000000
# max                          3.000000
#
#         NrAnulacoesPorMotivo_DESISTÊNCIA OU EXCLUSÃO DE FORMAÇÃO  \
# count                                                49.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_DESISTÊNCIA OU EXCLUSÃO DE MEDIDAS DE EMPREGO (EXCLUI TRABALHO SOCIALMENTE NECESSÁRIO)  \
# count                                                 4.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_DESISTÊNCIA OU EXCLUSÃO DE TRABALHO SOCIALMENTE NECESSÁRIO  \
# count                                                43.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_DETENÇÃO EM ESTABELECIMENTO PRISIONAL  \
# count                                                13.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_EMIGRAÇÃO, AUSÊNCIA DO PAÍS  \
# count                                        5590.000000
# unique                                               NaN
# top                                                  NaN
# freq                                                 NaN
# first                                                NaN
# last                                                 NaN
# mean                                            1.377281
# std                                             0.920271
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                            11.000000
#
#         NrAnulacoesPorMotivo_FALECIMENTO  \
# count                                3.0
# unique                               NaN
# top                                  NaN
# freq                                 NaN
# first                                NaN
# last                                 NaN
# mean                                 1.0
# std                                  0.0
# min                                  1.0
# 25%                                  1.0
# 50%                                  1.0
# 75%                                  1.0
# max                                  1.0
#
#         NrAnulacoesPorMotivo_FALTA A CONVOCATÓRIA  \
# count                                26568.000000
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# first                                         NaN
# last                                          NaN
# mean                                     1.447418
# std                                      0.847514
# min                                      1.000000
# 25%                                      1.000000
# 50%                                      1.000000
# 75%                                      2.000000
# max                                     12.000000
#
#         NrAnulacoesPorMotivo_FALTA AO CONTROLO  \
# count                             22487.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# first                                      NaN
# last                                       NaN
# mean                                  1.318851
# std                                   0.661378
# min                                   1.000000
# 25%                                   1.000000
# 50%                                   1.000000
# 75%                                   1.000000
# max                                   7.000000
#
#         NrAnulacoesPorMotivo_FALTA À APRESENTAÇÃO  \
# count                                  449.000000
# unique                                        NaN
# top                                           NaN
# freq                                          NaN
# first                                         NaN
# last                                          NaN
# mean                                     1.017817
# std                                      0.132435
# min                                      1.000000
# 25%                                      1.000000
# 50%                                      1.000000
# 75%                                      1.000000
# max                                      2.000000
#
#         NrAnulacoesPorMotivo_FREQUÊNCIA DE CURSO DE FORMAÇÃO PROFISSIONAL DO IEFP  \
# count                                          764.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.023560
# std                                              0.151774
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrAnulacoesPorMotivo_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAC  \
# count                                                 1.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   NaN
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAL  \
# count                                                 6.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAP  \
# count                                                14.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_FREQUÊNCIA DE FORMAÇÃO DO IEFP (ENTRADA SGFOR)  \
# count                                         3527.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.047916
# std                                              0.221442
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              3.000000
#
#         NrAnulacoesPorMotivo_FREQUÊNCIA DE FORMAÇÃO EM ENTIDADE EXTERNA AO IEFP  \
# count                                          422.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.078199
# std                                              0.268803
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrAnulacoesPorMotivo_INCAPACIDADE PROLONGADA / PERMANENTE PARA O TRABALHO  \
# count                                          308.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.042208
# std                                              0.216962
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              3.000000
#
#         NrAnulacoesPorMotivo_INCUMPRIMENTO DA APRESENTAÇÃO QUINZENAL  \
# count                                          1010.00000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                              1.00495
# std                                               0.07022
# min                                               1.00000
# 25%                                               1.00000
# 50%                                               1.00000
# 75%                                               1.00000
# max                                               2.00000
#
#         NrAnulacoesPorMotivo_INSCRIÇÃO CANDIDATURA EXTERNA  \
# count                                                 1.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   NaN
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_INSERÇÃO NOUTROS PROGRAMAS/MEDIDAS EMPREGO (SIEF)  \
# count                                          969.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.012384
# std                                              0.110649
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrAnulacoesPorMotivo_INSERÇÃO POR CONTA OUTRÉM, NA SEQUÊNCIA DE PROGRAMA  \
# count                                          221.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.009050
# std                                              0.094914
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrAnulacoesPorMotivo_INÍCIO DE LICENÇA DE MATERNIDADE, PATERNIDADE OU ADOPÇÃO  \
# count                                                16.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrAnulacoesPorMotivo_OUTROS MOTIVOS      ...       \
# count                           1409.000000      ...
# unique                                  NaN      ...
# top                                     NaN      ...
# freq                                    NaN      ...
# first                                   NaN      ...
# last                                    NaN      ...
# mean                               1.032647      ...
# std                                0.185593      ...
# min                                1.000000      ...
# 25%                                1.000000      ...
# 50%                                1.000000      ...
# 75%                                1.000000      ...
# max                                3.000000      ...
#
#         NrApresentacoesComResultado_COLOCAÇÃO - CANDIDATURA EXTERNA  \
# count                                                 2.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA DE OUTREM  \
# count                                        19499.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.532130
# std                                              1.178774
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              2.000000
# max                                             14.000000
#
#         NrApresentacoesComResultado_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA PRÓPRIA  \
# count                                          944.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.193856
# std                                              0.629366
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              6.000000
#
#         NrApresentacoesComResultado_CORRECÇÃO COLOCAÇÃO FME  \
# count                                                 3.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_CORRECÇÃO REINSCRIÇÃO FME  \
# count                                                 4.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_CRIAÇÃO DO PRÓPRIO EMPREGO  \
# count                                               111.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_CUMPRIMENTO SERVIÇO MILITAR  \
# count                                                 2.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_DESISTIU  \
# count                             948.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# first                                    NaN
# last                                     NaN
# mean                                1.034810
# std                                 0.210223
# min                                 1.000000
# 25%                                 1.000000
# 50%                                 1.000000
# 75%                                 1.000000
# max                                 3.000000
#
#         NrApresentacoesComResultado_DESISTÊNCIA OU EXCLUSÃO DE FORMAÇÃO  \
# count                                                49.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_DESISTÊNCIA OU EXCLUSÃO DE MEDIDAS DE EMPREGO (EXCLUI TRABALHO SOCIALMENTE NECESSÁRIO)  \
# count                                                 4.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_DESISTÊNCIA OU EXCLUSÃO DE TRABALHO SOCIALMENTE NECESSÁRIO  \
# count                                                43.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# ...
# max                                                   1.0
#
#         NrApresentacoesComResultado_INSERÇÃO NOUTROS PROGRAMAS/MEDIDAS EMPREGO (SIEF)  \
# count                                          969.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.012384
# std                                              0.110649
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrApresentacoesComResultado_INSERÇÃO POR CONTA OUTRÉM, NA SEQUÊNCIA DE PROGRAMA  \
# count                                          221.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.009050
# std                                              0.094914
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrApresentacoesComResultado_INÍCIO DE LICENÇA DE MATERNIDADE, PATERNIDADE OU ADOPÇÃO  \
# count                                                16.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_OUTROS MOTIVOS  \
# count                                  1409.000000
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# first                                          NaN
# last                                           NaN
# mean                                      1.032647
# std                                       0.185593
# min                                       1.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                       3.000000
#
#         NrApresentacoesComResultado_RECUSA DE EMPREGO CONVENIENTE  \
# count                                          290.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.013793
# std                                              0.116833
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrApresentacoesComResultado_RECUSA DE FORMALIZAÇÃO DE PPE  \
# count                                                 6.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_RECUSA DE FORMAÇÃO PROFISSIONAL  \
# count                                          801.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.007491
# std                                              0.099719
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              3.000000
#
#         NrApresentacoesComResultado_RECUSA DE INTERVENÇÃO  \
# count                                         1059.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.005666
# std                                              0.075093
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              2.000000
#
#         NrApresentacoesComResultado_RECUSA DE TRABALHO SOCIALMENTE NECESSÁRIO  \
# count                                                38.0
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                                  1.0
# std                                                   0.0
# min                                                   1.0
# 25%                                                   1.0
# 50%                                                   1.0
# 75%                                                   1.0
# max                                                   1.0
#
#         NrApresentacoesComResultado_REFORMOU-SE  \
# count                                      41.0
# unique                                      NaN
# top                                         NaN
# freq                                        NaN
# first                                       NaN
# last                                        NaN
# mean                                        1.0
# std                                         0.0
# min                                         1.0
# 25%                                         1.0
# 50%                                         1.0
# 75%                                         1.0
# max                                         1.0
#
#         NrApresentacoesComResultado_REINÍCIO DE ESTUDOS  \
# count                                              66.0
# unique                                              NaN
# top                                                 NaN
# freq                                                NaN
# first                                               NaN
# last                                                NaN
# mean                                                1.0
# std                                                 0.0
# min                                                 1.0
# 25%                                                 1.0
# 50%                                                 1.0
# 75%                                                 1.0
# max                                                 1.0
#
#         NrApresentacoesComResultado_TRANSFERÊNCIA DE CENTRO DE EMPREGO  \
# count                                          903.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.111849
# std                                              0.441354
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              1.000000
# max                                              5.000000
#
#         NrApresentacoesComResultado_TRANSFERÊNCIA REGIÕES AUTÓNOMAS  \
# count                                           35.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                             1.571429
# std                                              1.037126
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              2.000000
# max                                              5.000000
#
#         NrConvocatorias  NrDescendentesCargo  NrEncaminhamentos  \
# count     123701.000000                62479      123701.000000
# unique              NaN                   15                NaN
# top                 NaN                  0,0                NaN
# freq                NaN                36995                NaN
# first               NaN                  NaN                NaN
# last                NaN                  NaN                NaN
# mean           1.777496                  NaN           0.777706
# std            3.219120                  NaN           1.753240
# min            0.000000                  NaN           0.000000
# 25%            0.000000                  NaN           0.000000
# 50%            0.000000                  NaN           0.000000
# 75%            2.000000                  NaN           1.000000
# max           43.000000                  NaN          38.000000
#
#          NrInscricoes  NrIntervencoes  NrMudancasCategoria  NrPessoasCargo  \
# count   123701.000000   123701.000000        123701.000000    72546.000000
# unique            NaN             NaN                  NaN             NaN
# top               NaN             NaN                  NaN             NaN
# freq              NaN             NaN                  NaN             NaN
# first             NaN             NaN                  NaN             NaN
# last              NaN             NaN                  NaN             NaN
# mean         0.968497        2.855393             0.537320        1.213988
# std          1.501910        4.218423             2.964562        3.707174
# min          0.000000        0.000000             0.000000        0.000000
# 25%          0.000000        0.000000             0.000000        0.000000
# 50%          0.000000        1.000000             0.000000        1.000000
# 75%          1.000000        4.000000             0.000000        2.000000
# max         34.000000       92.000000           222.000000       99.000000
#
#         Qualificacao     RSI    Sexo        Utente
# count          91552  123701  123701  1.237010e+05
# unique             9       2       2           NaN
# top                3       N       F           NaN
# freq           31658  119743   65642           NaN
# first            NaN     NaN     NaN           NaN
# last             NaN     NaN     NaN           NaN
# mean             NaN     NaN     NaN  3.659528e+06
# std              NaN     NaN     NaN  1.572049e+06
# min              NaN     NaN     NaN  7.100000e+02
# 25%              NaN     NaN     NaN  2.454868e+06
# 50%              NaN     NaN     NaN  3.911257e+06
# 75%              NaN     NaN     NaN  4.757685e+06
# max              NaN     NaN     NaN  6.550048e+06
#
# [13 rows x 111 columns]

# %%
df.isnull().sum()
# Out:
# AreaCurso                                                                                                      101421
# AreaFormacao                                                                                                   100075
# CategoriaAtrib                                                                                                      0
# CnpAnterior                                                                                                     24014
# ConjugeMotivoIndisponibilidade                                                                                 123678
# CursoAnoConclusao                                                                                              101326
# CursoEstabelecimentoEnsinoSup                                                                                  101349
# Data                                                                                                                0
# DataNascimento                                                                                                  76478
# DiasDesemprego                                                                                                      0
# Empregado                                                                                                           0
# EstadoCivil                                                                                                         0
# FormacaoProf                                                                                                    92195
# HabilitacaoEscolar                                                                                                  0
# Idade                                                                                                               0
# LTU                                                                                                                 0
# Nacionalidade                                                                                                       0
# NivelDeficiencia                                                                                                    0
# NrAnulacoes                                                                                                         0
# NrAnulacoesPorMotivo_CADUCIDADE DO DOCUMENTO DE IDENTIFICAÇÃO                                                  123507
# NrAnulacoesPorMotivo_COLOCAÇÃO - CANDIDATURA EXTERNA                                                           123699
# NrAnulacoesPorMotivo_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA DE OUTREM                                         104202
# NrAnulacoesPorMotivo_COLOCAÇÃO POR MEIOS PRÓPRIOS, POR CONTA PRÓPRIA                                           122757
# NrAnulacoesPorMotivo_CORRECÇÃO COLOCAÇÃO FME                                                                   123698
# NrAnulacoesPorMotivo_CORRECÇÃO REINSCRIÇÃO FME                                                                 123697
# NrAnulacoesPorMotivo_CRIAÇÃO DO PRÓPRIO EMPREGO                                                                123590
# NrAnulacoesPorMotivo_CUMPRIMENTO SERVIÇO MILITAR                                                               123699
# NrAnulacoesPorMotivo_DESISTIU                                                                                  122753
# NrAnulacoesPorMotivo_DESISTÊNCIA OU EXCLUSÃO DE FORMAÇÃO                                                       123652
# NrAnulacoesPorMotivo_DESISTÊNCIA OU EXCLUSÃO DE MEDIDAS DE EMPREGO (EXCLUI TRABALHO SOCIALMENTE NECESSÁRIO)    123697
#                                                                                                                 ...
# NrApresentacoesComResultado_FREQUÊNCIA DE ESTÁGIO PROFISSIONAL PEPAP                                           123687
# NrApresentacoesComResultado_FREQUÊNCIA DE FORMAÇÃO DO IEFP (ENTRADA SGFOR)                                     120174
# NrApresentacoesComResultado_FREQUÊNCIA DE FORMAÇÃO EM ENTIDADE EXTERNA AO IEFP                                 123279
# NrApresentacoesComResultado_INCAPACIDADE PROLONGADA / PERMANENTE PARA O TRABALHO                               123393
# NrApresentacoesComResultado_INCUMPRIMENTO DA APRESENTAÇÃO QUINZENAL                                            122691
# NrApresentacoesComResultado_INSCRIÇÃO CANDIDATURA EXTERNA                                                      123700
# NrApresentacoesComResultado_INSERÇÃO NOUTROS PROGRAMAS/MEDIDAS EMPREGO (SIEF)                                  122732
# NrApresentacoesComResultado_INSERÇÃO POR CONTA OUTRÉM, NA SEQUÊNCIA DE PROGRAMA                                123480
# NrApresentacoesComResultado_INÍCIO DE LICENÇA DE MATERNIDADE, PATERNIDADE OU ADOPÇÃO                           123685
# NrApresentacoesComResultado_OUTROS MOTIVOS                                                                     122292
# NrApresentacoesComResultado_RECUSA DE EMPREGO CONVENIENTE                                                      123411
# NrApresentacoesComResultado_RECUSA DE FORMALIZAÇÃO DE PPE                                                      123695
# NrApresentacoesComResultado_RECUSA DE FORMAÇÃO PROFISSIONAL                                                    122900
# NrApresentacoesComResultado_RECUSA DE INTERVENÇÃO                                                              122642
# NrApresentacoesComResultado_RECUSA DE TRABALHO SOCIALMENTE NECESSÁRIO                                          123663
# NrApresentacoesComResultado_REFORMOU-SE                                                                        123660
# NrApresentacoesComResultado_REINÍCIO DE ESTUDOS                                                                123635
# NrApresentacoesComResultado_TRANSFERÊNCIA DE CENTRO DE EMPREGO                                                 122798
# NrApresentacoesComResultado_TRANSFERÊNCIA REGIÕES AUTÓNOMAS                                                    123666
# NrConvocatorias                                                                                                     0
# NrDescendentesCargo                                                                                             61222
# NrEncaminhamentos                                                                                                   0
# NrInscricoes                                                                                                        0
# NrIntervencoes                                                                                                      0
# NrMudancasCategoria                                                                                                 0
# NrPessoasCargo                                                                                                  51155
# Qualificacao                                                                                                    32149
# RSI                                                                                                                 0
# Sexo                                                                                                                0
# Utente                                                                                                              0
# Length: 111, dtype: int64

# %%
pandasprof.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>111 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>123701 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>58.8% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>104.8 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>888.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>70 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>18 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>22 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>AreaCurso</code> has 101421 / 82.0% missing values <span class="label label-default">Missing</span></l><li><code>AreaCurso</code> has a high cardinality: 1529 distinct values  <span class="label label-warning">Warning</span></l><li><code>AreaFormacao</code> has 100075 / 80.9% missing values <span class="label label-default">Missing</span></l><li><code>AreaFormacao</code> has a high cardinality: 101 distinct values  <span class="label label-warning">Warning</span></l><li><code>CnpAnterior</code> has 24014 / 19.4% missing values <span class="label label-default">Missing</span></l><li><code>CnpAnterior</code> has a high cardinality: 1130 distinct values  <span class="label label-warning">Warning</span></l><li><code>ConjugeMotivoIndisponibilidade</code> has 123678 / 100.0% missing values <span class="label label-default">Missing</span></l><li><code>CursoAnoConclusao</code> has 101326 / 81.9% missing values <span class="label label-default">Missing</span></l><li><code>CursoAnoConclusao</code> has a high cardinality: 59 distinct values  <span class="label label-warning">Warning</span></l><li><code>CursoEstabelecimentoEnsinoSup</code> has 101349 / 81.9% missing values <span class="label label-default">Missing</span></l><li><code>CursoEstabelecimentoEnsinoSup</code> has a high cardinality: 320 distinct values  <span class="label label-warning">Warning</span></l><li><code>DataNascimento</code> has 76478 / 61.8% missing values <span class="label label-default">Missing</span></l><li><code>DataNascimento

# %% [markdown]
# ## Limpeza das variáveis

# %% [markdown]
# Substituição de `None` por 0's e correcção do Types

# %%
# DataNascimento
df['DataNascimento'].fillna(value=np.nan, inplace = True)
df['DataNascimento'] = pd.to_datetime(df['DataNascimento'])

# %%
# Substitui por 0 todos Nones nas colunas que 
# começam por NrAnulacoesPorMotivo ou NrApresentacoesComResultado
filter_col = [col for col in df if col.startswith('NrAnulacoesPorMotivo') 
                                   or col.startswith('NrApresentacoesComResultado')]

for col in filter_col:
    df[col].fillna(value=0, inplace = True);
    df[col]=df[col].astype('int');

# %%
# Empregado?
df['Empregado'] = df['Empregado'].astype('category')

# %% [markdown]
# ## Novas Features

# %% [markdown]
# ### Idade

# %%
df['IdadeCalculada'] = (df['Data']-df['DataNascimento']).astype('timedelta64[Y]')
# Não tem grande utilidade...Apagar

# %% [markdown]
# ***

# %% [markdown]
# ## Análise Exploratória Univariada

# %% [markdown]
# ### LTU

# %%
df['LTU'] = df['LTU'].astype('category');
df['LTU'].describe()
# Out:
# count     123701
# unique         3
# top            ?
# freq       75608
# Name: LTU, dtype: object

# %%
sns.countplot(x='LTU', data=df);

# %% [markdown]
# ### DiasDesemprego

# %%
# Dataset contendo apenas utentes que se sabe quando acabaram por ficar empregados
df_empregados = df[(df['Empregado']=='S')]

# %%
sns.distplot(df_empregados['DiasDesemprego'])
plt.xlim(-100, 2000);

# %%
df_empregados['DiasDesemprego'].describe()
# Out:
# count    23215.000000
# mean       214.349343
# std        262.364293
# min          0.000000
# 25%         41.000000
# 50%        115.000000
# 75%        293.000000
# max       3273.000000
# Name: DiasDesemprego, dtype: float64

# %%
#skewness e kurtosis
print("Skewness: %f" % df['DiasDesemprego'].skew())
print("Kurtosis: %f" % df['DiasDesemprego'].kurt())
# Out:
# Skewness: 34.710146
# Kurtosis: 5270.179240

# %% [markdown]
# ### Idade

# %%
sns.distplot(df['Idade'].dropna(), bins=100);

# %% [markdown]
# Estranhamente parece que não existe observações relativas a algumas idades

# %% [markdown]
# ***

# %% [markdown]
# ## Análise Exploratória Multivariada

# %% [markdown]
# ### Distribuição de Idade / LTU

# %%
df_LTU = df[df.LTU!='?']
df_LTU.LTU.cat.remove_unused_categories(inplace = True); ## Remove a categoria '?'

# %%
sns.violinplot(x='LTU', y='Idade', hue="Sexo", data=df_LTU, split=True, scale="count", inner="quartile");

# %% [markdown]
# A mediana das Idades das populações LTU e N/LTU parece

# %% [markdown]
# ### DiasDesemprego-Sexo

# %% [markdown]
# Comparação das populações do sexo Masculino e Feminino em relação dos dias de desemprego.<br>
# **Nota:** Deve-se filtar apenas as observações que resultaram em emprego pois só nesses casos sabemos ao certo quantos foram os dias que estiveram desempegados

# %%
sns.boxplot(x='Sexo', y='DiasDesemprego', data=df_empregados)
plt.ylim(0, 700);

# %% [markdown]
# Olhando para a Mediana, aparentemente os utentes do sexo masculino ficam mais tempo desempregados...

# %%
print("Mediana 'DiasDesemprego' (Sexo M): {:.0f} dias".format(df_empregados[df.Sexo == 'M']['DiasDesemprego'].median()))
print("Mediana 'DiasDesemprego' (Sexo F): {:.0f} dias".format(df_empregados[df.Sexo == 'F']['DiasDesemprego'].median()))
# Out:
# Mediana 'DiasDesemprego' (Sexo M): 125 dias
# Mediana 'DiasDesemprego' (Sexo F): 106 dias

# %% [markdown]
# ## Funcoes Auxiliares

# %% [markdown]
# ### Exportar df para MySQL

# %%
# Truncar column names a 64 caracteres e substituir caracteres acentuados
import re
import unidecode
oldColNames = [col for col in df]
newColNames = [ re.sub('[^A-Za-z0-9]+', '',unidecode.unidecode((col)))[:64] for col in df ]

df.rename(columns=dict(zip(oldColNames, newColNames)), inplace=True)

# %%
# Guarda Dataframe em tabela MySQL
from sqlalchemy import create_engine
PASSWORD_FILENAME = './password.txt'
with open(PASSWORD_FILENAME) as f: mysqlpass = f.read()
engine = create_engine('mysql+pymysql://helio.b.teixeira:{}@vsrv01.inesctec.pt:3306/datasets'.format(mysqlpass.strip()))
df.to_sql('DatasetModelo', engine, if_exists='replace')

# %% [markdown]
# <div class="alert alert-block alert-info">
# - __[Shortcuts](https://www.cheatography.com/weidadeyue/cheat-sheets/jupyter-notebook/)__
# - __[Markdown](http://datascience.ibm.com/blog/markdown-for-jupyter-notebooks-cheatsheet/)__
